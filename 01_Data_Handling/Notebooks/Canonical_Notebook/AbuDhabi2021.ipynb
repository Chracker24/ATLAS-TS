# %% [markdown]
# # Introduction to the Canonical Dataset and what it will be used for

# %% [markdown]
# ### Canonical Dataset
#
# The canonical dataset is a single, clean time-series used as the development and validation reference for MTS-IE. It serves as the controlled environment in which the full pipeline—data ingestion, regime detection, anomaly detection, forecasting, uncertainty estimation, and scenario simulation—is implemented, debugged, and verified end-to-end.
#
# This dataset is **not** used to train a global model or encode historical knowledge. Instead, it provides a stable sandbox for building and testing system logic before the same stateless engine is applied unchanged to other datasets for validation and robustness checks.

# %% [markdown]
# ### Why 2021 Abu Dhabi Grand Prix?
#
# The 2021 Abu Dhabi Grand Prix is used as the canonical dataset because it exhibits clear regime shifts, abrupt volatility changes, and decision-critical uncertainty within a short, well-defined time window. These characteristics make it ideal for developing and validating MTS-IE’s core capabilities—regime detection, anomaly detection, and uncertainty-aware simulation—without relying on long historical spans.

# %%
# Importing the necessary libraries

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Reading the csv file 

season_2021 = pd.read_csv("../../Data/Archive/season_2021.csv")
season_2021.tail()
# Out:
#       Driver  LapTime  LapNumber  Stint  Sector1Time  Sector2Time  \
# 23893    HAM   78.003       78.0    3.0       20.193       36.406
# 23894    VET   77.071       78.0    2.0       20.335       35.978
# 23895    NOR   76.101       78.0    2.0       19.692       35.738
# 23896    PER   75.307       78.0    2.0       19.850       35.110
# 23897    VER   76.829       78.0    2.0       20.258       35.742
#
#        Sector3Time Compound             Team  Deleted  Season    Race
# 23893       21.404     SOFT         Mercedes    False    2021  Monaco
# 23894       20.758     HARD     Aston Martin    False    2021  Monaco
# 23895       20.671     HARD          McLaren    False    2021  Monaco
# 23896       20.347     HARD  Red Bull Racing    False    2021  Monaco
# 23897       20.829     HARD  Red Bull Racing    False    2021  Monaco

# %%
# Copying the Abu Dhabi Grand Prix into a separate dataframe

AD21 = season_2021[season_2021["Race"] == "Abu Dhabi"].copy().reset_index(drop = True)
AD21
# Out:
#     Driver  LapTime  LapNumber  Stint  Sector1Time  Sector2Time  Sector3Time  \
# 0      BOT   97.280        1.0    1.0          NaN       39.157       35.555
# 1      RAI  101.610        1.0    1.0          NaN       40.387       36.246
# 2      GAS   99.330        1.0    1.0          NaN       39.238       36.292
# 3      TSU   96.600        1.0    1.0          NaN       39.009       34.934
# 4      RUS  102.644        1.0    1.0          NaN       40.204       37.282
# ..     ...      ...        ...    ...          ...          ...          ...
# 972    NOR   86.762       58.0    3.0       17.467       37.799       31.496
# 973    TSU   87.954       58.0    3.0       17.508       38.093       32.353
# 974    VER   86.618       58.0    4.0       17.476       38.455       30.687
# 975    OCO   88.249       58.0    2.0       17.774       37.845       32.630
# 976    BOT   90.479       58.0    2.0       17.723       38.788       33.968
#
#     Compound               Team  Deleted  Season       Race
# 0     MEDIUM           Mercedes    False    2021  Abu Dhabi
# 1     MEDIUM  Alfa Romeo Racing    False    2021  Abu Dhabi
# 2       HARD         AlphaTauri    False    2021  Abu Dhabi
# 3     MEDIUM         AlphaTauri    False    2021  Abu Dhabi
# 4     MEDIUM           Williams    False    2021  Abu Dhabi
# ..       ...                ...      ...     ...        ...
# 972   MEDIUM            McLaren    False    2021  Abu Dhabi
# 973     SOFT         AlphaTauri    False    2021  Abu Dhabi
# 974     SOFT    Red Bull Racing    False    2021  Abu Dhabi
# 975     HARD             Alpine    False    2021  Abu Dhabi
# 976     HARD           Mercedes    False    2021  Abu Dhabi
#
# [977 rows x 12 columns]

# %% [markdown]
# # Time-Series Visualization

# %% [markdown]
# Lets look into Sir Lewis Hamilton's lap times first

# %%
HAM_time = AD21[AD21["Driver"] == "HAM"].copy().reset_index(drop=True)
HAM_time
# Out:
#    Driver  LapTime  LapNumber  Stint  Sector1Time  Sector2Time  Sector3Time  \
# 0     HAM   91.686        1.0    1.0          NaN       38.189       33.146
# 1     HAM   88.791        2.0    1.0       17.961       38.053       32.777
# 2     HAM   88.587        3.0    1.0       18.136       37.860       32.591
# 3     HAM   88.789        4.0    1.0       18.013       38.111       32.665
# 4     HAM   88.630        5.0    1.0       18.001       38.137       32.492
# 5     HAM   88.593        6.0    1.0       17.981       38.201       32.411
# 6     HAM   88.550        7.0    1.0       17.993       38.122       32.435
# 7     HAM   88.585        8.0    1.0       18.031       38.157       32.397
# 8     HAM   88.356        9.0    1.0       18.063       38.148       32.145
# 9     HAM   88.216       10.0    1.0       17.921       38.146       32.149
# 10    HAM   88.134       11.0    1.0       17.906       37.996       32.232
# 11    HAM   88.566       12.0    1.0       17.926       38.155       32.485
# 12    HAM   88.258       13.0    1.0       17.860       38.112       32.286
# 13    HAM   90.253       14.0    1.0       17.828       38.105       34.320
# 14    HAM  108.755       15.0    2.0       38.381       37.984       32.390
# 15    HAM   87.833       16.0    2.0       17.915       37.863       32.055
# 16    HAM   87.780       17.0    2.0       17.840       37.858       32.082
# 17    HAM   87.889       18.0    2.0       17.945       37.658       32.286
# 18    HAM   88.232       19.0    2.0       17.832       37.861       32.539
# 19    HAM   93.443       20.0    2.0       17.991       39.318       36.134
# 20    HAM   90.485       21.0    2.0       19.193       39.228       32.064
# 21    HAM   88.006       22.0    2.0       17.866       37.904       32.236
# 22    HAM   87.663       23.0    2.0       17.739       37.762       32.162
# 23    HAM   87.979       24.0    2.0       17.818       37.815       32.346
# 24    HAM   87.870       25.0    2.0       17.823       37.765       32.282
# 25    HAM   88.077       26.0    2.0       17.834       38.107       32.136
# 26    HAM   87.975       27.0    2.0       17.837       37.780       32.358
# 27    HAM   88.143       28.0    2.0       17.893       37.785       32.465
# 28    HAM   87.484       29.0    2.0       17.802       37.703       31.979
# 29    HAM   87.508       30.0    2.0       17.714       37.633       32.161
# 30    HAM   87.495       31.0    2.0       17.788       37.728       31.979
# 31    HAM   87.444       32.0    2.0       17.757       37.702       31.985
# 32    HAM   87.742       33.0    2.0       17.642       37.863       32.237
# 33    HAM   87.201       34.0    2.0       17.747       37.458       31.996
# 34    HAM   87.591       35.0    2.0       17.721       37.689       32.181
# 35    HAM  101.467       36.0    2.0       17.702       42.488       41.277
# 36    HAM  116.216       37.0    2.0       24.815       49.338       42.063
# 37    HAM   90.157       38.0    2.0       20.798       37.554       31.805
# 38    HAM   86.762       39.0    2.0       17.614       37.403       31.745
# 39    HAM   87.387       40.0    2.0       17.634       37.484       32.269
# 40    HAM   86.718       41.0    2.0       17.675       37.365       31.678
# 41    HAM   86.782       42.0    2.0       17.662       37.532       31.588
# 42    HAM   86.615       43.0    2.0       17.600       37.290       31.725
# 43    HAM   87.020       44.0    2.0       17.666       37.535       31.819
# 44    HAM   86.966       45.0    2.0       17.617       37.334       32.015
# 45    HAM   87.270       46.0    2.0       17.618       37.341       32.311
# 46    HAM   87.683       47.0    2.0       17.723       37.400       32.560
# 47    HAM   87.553       48.0    2.0       17.620       37.444       32.489
# 48    HAM   86.875       49.0    2.0       17.724       37.522       31.629
# 49    HAM   86.784       50.0    2.0       17.629       37.369       31.786
# 50    HAM   86.934       51.0    2.0       17.711       37.544       31.679
# 51    HAM   86.833       52.0    2.0       17.608       37.407       31.818
# 52    HAM   98.574       53.0    2.0       17.669       37.336       43.569
# 53    HAM  142.911       54.0    2.0       20.441       63.942       58.528
# 54    HAM  145.761       56.0    2.0       30.973       59.223       55.565
# 55    HAM  148.331       57.0    2.0       28.439       62.795       57.097
# 56    HAM   89.330       58.0    2.0       17.662       38.725       32.943
#
#    Compound      Team  Deleted  Season       Race
# 0    MEDIUM  Mercedes    False    2021  Abu Dhabi
# 1    MEDIUM  Mercedes    False    2021  Abu Dhabi
# 2    MEDIUM  Mercedes    False    2021  Abu Dhabi
# 3    MEDIUM  Mercedes    False    2021  Abu Dhabi
# 4    MEDIUM  Mercedes    False    2021  Abu Dhabi
# 5    MEDIUM  Mercedes    False    2021  Abu Dhabi
# 6    MEDIUM  Mercedes    False    2021  Abu Dhabi
# 7    MEDIUM  Mercedes    False    2021  Abu Dhabi
# 8    MEDIUM  Mercedes    False    2021  Abu Dhabi
# 9    MEDIUM  Mercedes    False    2021  Abu Dhabi
# 10   MEDIUM  Mercedes    False    2021  Abu Dhabi
# 11   MEDIUM  Mercedes    False    2021  Abu Dhabi
# 12   MEDIUM  Mercedes    False    2021  Abu Dhabi
# 13   MEDIUM  Mercedes    False    2021  Abu Dhabi
# 14     HARD  Mercedes    False    2021  Abu Dhabi
# 15     HARD  Mercedes    False    2021  Abu Dhabi
# 16     HARD  Mercedes    False    2021  Abu Dhabi
# 17     HARD  Mercedes    False    2021  Abu Dhabi
# 18     HARD  Mercedes    False    2021  Abu Dhabi
# 19     HARD  Mercedes    False    2021  Abu Dhabi
# 20     HARD  Mercedes    False    2021  Abu Dhabi
# 21     HARD  Mercedes    False    2021  Abu Dhabi
# 22     HARD  Mercedes    False    2021  Abu Dhabi
# 23     HARD  Mercedes    False    2021  Abu Dhabi
# 24     HARD  Mercedes    False    2021  Abu Dhabi
# 25     HARD  Mercedes    False    2021  Abu Dhabi
# 26     HARD  Mercedes    False    2021  Abu Dhabi
# 27     HARD  Mercedes    False    2021  Abu Dhabi
# 28     HARD  Mercedes    False    2021  Abu Dhabi
# 29     HARD  Mercedes    False    2021  Abu Dhabi
# 30     HARD  Mercedes    False    2021  Abu Dhabi
# 31     HARD  Mercedes    False    2021  Abu Dhabi
# 32     HARD  Mercedes    False    2021  Abu Dhabi
# 33     HARD  Mercedes    False    2021  Abu Dhabi
# 34     HARD  Mercedes    False    2021  Abu Dhabi
# 35     HARD  Mercedes    False    2021  Abu Dhabi
# 36     HARD  Mercedes    False    2021  Abu Dhabi
# 37     HARD  Mercedes    False    2021  Abu Dhabi
# 38     HARD  Mercedes    False    2021  Abu Dhabi
# 39     HARD  Mercedes    False    2021  Abu Dhabi
# 40     HARD  Mercedes    False    2021  Abu Dhabi
# 41     HARD  Mercedes    False    2021  Abu Dhabi
# 42     HARD  Mercedes    False    2021  Abu Dhabi
# 43     HARD  Mercedes    False    2021  Abu Dhabi
# 44     HARD  Mercedes    False    2021  Abu Dhabi
# 45     HARD  Mercedes    False    2021  Abu Dhabi
# 46     HARD  Mercedes    False    2021  Abu Dhabi
# 47     HARD  Mercedes    False    2021  Abu Dhabi
# 48     HARD  Mercedes    False    2021  Abu Dhabi
# 49     HARD  Mercedes    False    2021  Abu Dhabi
# 50     HARD  Mercedes    False    2021  Abu Dhabi
# 51     HARD  Mercedes    False    2021  Abu Dhabi
# 52     HARD  Mercedes    False    2021  Abu Dhabi
# 53     HARD  Mercedes    False    2021  Abu Dhabi
# 54     HARD  Mercedes    False    2021  Abu Dhabi
# 55     HARD  Mercedes    False    2021  Abu Dhabi
# 56     HARD  Mercedes    False    2021  Abu Dhabi

# %%
HAM_time = HAM_time.sort_values("LapNumber").reset_index(drop=True)

# %% [markdown]
# ## Now lets see Hamilton's lap time versus lap number

# %%
plt.figure(figsize=(10,4))

plt.plot(HAM_time["LapNumber"], HAM_time["LapTime"])
plt.title("LapNumber vs LapTime - HAM")
plt.xlabel("LapNumber")
plt.ylabel("LapTime")

plt.show()

# %% [markdown]
# ## Rolling mean (Trends)

# %%
# Lets start the window with 5 and then progress based on the graphs
window = 5
HAM_time["rolling_mean"] = (HAM_time["LapTime"].rolling(window = window, min_periods=5).mean())
HAM_time
# Out:
#    Driver  LapTime  LapNumber  Stint  Sector1Time  Sector2Time  Sector3Time  \
# 0     HAM   91.686        1.0    1.0          NaN       38.189       33.146
# 1     HAM   88.791        2.0    1.0       17.961       38.053       32.777
# 2     HAM   88.587        3.0    1.0       18.136       37.860       32.591
# 3     HAM   88.789        4.0    1.0       18.013       38.111       32.665
# 4     HAM   88.630        5.0    1.0       18.001       38.137       32.492
# 5     HAM   88.593        6.0    1.0       17.981       38.201       32.411
# 6     HAM   88.550        7.0    1.0       17.993       38.122       32.435
# 7     HAM   88.585        8.0    1.0       18.031       38.157       32.397
# 8     HAM   88.356        9.0    1.0       18.063       38.148       32.145
# 9     HAM   88.216       10.0    1.0       17.921       38.146       32.149
# 10    HAM   88.134       11.0    1.0       17.906       37.996       32.232
# 11    HAM   88.566       12.0    1.0       17.926       38.155       32.485
# 12    HAM   88.258       13.0    1.0       17.860       38.112       32.286
# 13    HAM   90.253       14.0    1.0       17.828       38.105       34.320
# 14    HAM  108.755       15.0    2.0       38.381       37.984       32.390
# 15    HAM   87.833       16.0    2.0       17.915       37.863       32.055
# 16    HAM   87.780       17.0    2.0       17.840       37.858       32.082
# 17    HAM   87.889       18.0    2.0       17.945       37.658       32.286
# 18    HAM   88.232       19.0    2.0       17.832       37.861       32.539
# 19    HAM   93.443       20.0    2.0       17.991       39.318       36.134
# 20    HAM   90.485       21.0    2.0       19.193       39.228       32.064
# 21    HAM   88.006       22.0    2.0       17.866       37.904       32.236
# 22    HAM   87.663       23.0    2.0       17.739       37.762       32.162
# 23    HAM   87.979       24.0    2.0       17.818       37.815       32.346
# 24    HAM   87.870       25.0    2.0       17.823       37.765       32.282
# 25    HAM   88.077       26.0    2.0       17.834       38.107       32.136
# 26    HAM   87.975       27.0    2.0       17.837       37.780       32.358
# 27    HAM   88.143       28.0    2.0       17.893       37.785       32.465
# 28    HAM   87.484       29.0    2.0       17.802       37.703       31.979
# 29    HAM   87.508       30.0    2.0       17.714       37.633       32.161
# 30    HAM   87.495       31.0    2.0       17.788       37.728       31.979
# 31    HAM   87.444       32.0    2.0       17.757       37.702       31.985
# 32    HAM   87.742       33.0    2.0       17.642       37.863       32.237
# 33    HAM   87.201       34.0    2.0       17.747       37.458       31.996
# 34    HAM   87.591       35.0    2.0       17.721       37.689       32.181
# 35    HAM  101.467       36.0    2.0       17.702       42.488       41.277
# 36    HAM  116.216       37.0    2.0       24.815       49.338       42.063
# 37    HAM   90.157       38.0    2.0       20.798       37.554       31.805
# 38    HAM   86.762       39.0    2.0       17.614       37.403       31.745
# 39    HAM   87.387       40.0    2.0       17.634       37.484       32.269
# 40    HAM   86.718       41.0    2.0       17.675       37.365       31.678
# 41    HAM   86.782       42.0    2.0       17.662       37.532       31.588
# 42    HAM   86.615       43.0    2.0       17.600       37.290       31.725
# 43    HAM   87.020       44.0    2.0       17.666       37.535       31.819
# 44    HAM   86.966       45.0    2.0       17.617       37.334       32.015
# 45    HAM   87.270       46.0    2.0       17.618       37.341       32.311
# 46    HAM   87.683       47.0    2.0       17.723       37.400       32.560
# 47    HAM   87.553       48.0    2.0       17.620       37.444       32.489
# 48    HAM   86.875       49.0    2.0       17.724       37.522       31.629
# 49    HAM   86.784       50.0    2.0       17.629       37.369       31.786
# 50    HAM   86.934       51.0    2.0       17.711       37.544       31.679
# 51    HAM   86.833       52.0    2.0       17.608       37.407       31.818
# 52    HAM   98.574       53.0    2.0       17.669       37.336       43.569
# 53    HAM  142.911       54.0    2.0       20.441       63.942       58.528
# 54    HAM  145.761       56.0    2.0       30.973       59.223       55.565
# 55    HAM  148.331       57.0    2.0       28.439       62.795       57.097
# 56    HAM   89.330       58.0    2.0       17.662       38.725       32.943
#
#    Compound      Team  Deleted  Season       Race  rolling_mean
# 0    MEDIUM  Mercedes    False    2021  Abu Dhabi           NaN
# 1    MEDIUM  Mercedes    False    2021  Abu Dhabi           NaN
# 2    MEDIUM  Mercedes    False    2021  Abu Dhabi           NaN
# 3    MEDIUM  Mercedes    False    2021  Abu Dhabi           NaN
# 4    MEDIUM  Mercedes    False    2021  Abu Dhabi       89.2966
# 5    MEDIUM  Mercedes    False    2021  Abu Dhabi       88.6780
# 6    MEDIUM  Mercedes    False    2021  Abu Dhabi       88.6298
# 7    MEDIUM  Mercedes    False    2021  Abu Dhabi       88.6294
# 8    MEDIUM  Mercedes    False    2021  Abu Dhabi       88.5428
# 9    MEDIUM  Mercedes    False    2021  Abu Dhabi       88.4600
# 10   MEDIUM  Mercedes    False    2021  Abu Dhabi       88.3682
# 11   MEDIUM  Mercedes    False    2021  Abu Dhabi       88.3714
# 12   MEDIUM  Mercedes    False    2021  Abu Dhabi       88.3060
# 13   MEDIUM  Mercedes    False    2021  Abu Dhabi       88.6854
# 14     HARD  Mercedes    False    2021  Abu Dhabi       92.7932
# 15     HARD  Mercedes    False    2021  Abu Dhabi       92.7330
# 16     HARD  Mercedes    False    2021  Abu Dhabi       92.5758
# 17     HARD  Mercedes    False    2021  Abu Dhabi       92.5020
# 18     HARD  Mercedes    False    2021  Abu Dhabi       92.0978
# 19     HARD  Mercedes    False    2021  Abu Dhabi       89.0354
# 20     HARD  Mercedes    False    2021  Abu Dhabi       89.5658
# 21     HARD  Mercedes    False    2021  Abu Dhabi       89.6110
# 22     HARD  Mercedes    False    2021  Abu Dhabi       89.5658
# 23     HARD  Mercedes    False    2021  Abu Dhabi       89.5152
# 24     HARD  Mercedes    False    2021  Abu Dhabi       88.4006
# 25     HARD  Mercedes    False    2021  Abu Dhabi       87.9190
# 26     HARD  Mercedes    False    2021  Abu Dhabi       87.9128
# 27     HARD  Mercedes    False    2021  Abu Dhabi       88.0088
# 28     HARD  Mercedes    False    2021  Abu Dhabi       87.9098
# 29     HARD  Mercedes    False    2021  Abu Dhabi       87.8374
# 30     HARD  Mercedes    False    2021  Abu Dhabi       87.7210
# 31     HARD  Mercedes    False    2021  Abu Dhabi       87.6148
# 32     HARD  Mercedes    False    2021  Abu Dhabi       87.5346
# 33     HARD  Mercedes    False    2021  Abu Dhabi       87.4780
# 34     HARD  Mercedes    False    2021  Abu Dhabi       87.4946
# 35     HARD  Mercedes    False    2021  Abu Dhabi       90.2890
# 36     HARD  Mercedes    False    2021  Abu Dhabi       96.0434
# 37     HARD  Mercedes    False    2021  Abu Dhabi       96.5264
# 38     HARD  Mercedes    False    2021  Abu Dhabi       96.4386
# 39     HARD  Mercedes    False    2021  Abu Dhabi       96.3978
# 40     HARD  Mercedes    False    2021  Abu Dhabi       93.4480
# 41     HARD  Mercedes    False    2021  Abu Dhabi       87.5612
# 42     HARD  Mercedes    False    2021  Abu Dhabi       86.8528
# 43     HARD  Mercedes    False    2021  Abu Dhabi       86.9044
# 44     HARD  Mercedes    False    2021  Abu Dhabi       86.8202
# 45     HARD  Mercedes    False    2021  Abu Dhabi       86.9306
# 46     HARD  Mercedes    False    2021  Abu Dhabi       87.1108
# 47     HARD  Mercedes    False    2021  Abu Dhabi       87.2984
# 48     HARD  Mercedes    False    2021  Abu Dhabi       87.2694
# 49     HARD  Mercedes    False    2021  Abu Dhabi       87.2330
# 50     HARD  Mercedes    False    2021  Abu Dhabi       87.1658
# 51     HARD  Mercedes    False    2021  Abu Dhabi       86.9958
# 52     HARD  Mercedes    False    2021  Abu Dhabi       89.2000
# 53     HARD  Mercedes    False    2021  Abu Dhabi      100.4072
# 54     HARD  Mercedes    False    2021  Abu Dhabi      112.2026
# 55     HARD  Mercedes    False    2021  Abu Dhabi      124.4820
# 56     HARD  Mercedes    False    2021  Abu Dhabi      124.9814

# %%
plt.figure(figsize=(10,3))
plt.plot(HAM_time["LapNumber"],HAM_time["LapTime"],
alpha=0.4,
label="Raw"
)

plt.plot(HAM_time["LapNumber"], HAM_time["rolling_mean"],
linewidth = 2,
label="Rolling mean"
)

plt.xlabel("LapNumber")
plt.ylabel("LapTime (s)")
plt.title("Hamilton Lap Times – Rolling Mean")
plt.legend()

plt.show()

# %% [markdown]
# ## Rolling Variance (Volatility)

# %%
HAM_time["rolling_variance"] = HAM_time["LapTime"].rolling(window = window, min_periods=5).var()

# %%
plt.figure(figsize=(10,3))


plt.plot(HAM_time["LapNumber"], HAM_time["rolling_variance"],
linewidth = 2,
label="Rolling Variance"
)

plt.xlabel("LapNumber")
plt.ylabel("LapTime (s)")
plt.title("Hamilton Lap Times – Rolling Variance")
plt.legend()

plt.show()

# %% [markdown]
# # Saving the Dataframe as a Canonical CSV file

# %%
HAM_time = HAM_time.drop_duplicates(subset="LapNumber")
HAM_time.to_csv("../../Data/Canonical/lewisHamilton_AbuDhabi_2021.csv", index=False)
